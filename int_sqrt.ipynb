# %% [markdown]
# ![int_sqrt.png](attachment:int_sqrt.png)

# %%
def solution(n):
    sqrt = n ** (1/2)    # n의 제곱근은 sqrt
    if sqrt % 1 == 0:    # n이 sqrt의 제곱이라면
        return (sqrt + 1) ** 2   # sqrt + 1 의 제곱을 빈환한다
    return -1            # 그렇지 않다면 -1을 반환한다


# 입출력 예 출력해보기
print(solution(121))
print(solution(3))
# Out:
# 144.0
# -1
