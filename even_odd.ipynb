# %% [markdown]
# ![even_odd.png](attachment:even_odd.png)

# %%
def solution(num):      # num 함수 선언
    if num % 2 == 0:    # num이 짝수라면 
        return "Even"   # Even 반환
    else:               # 홀수라면
        return "Odd"    # Odd 반환

# 입출력 예
print(solution(3))
print(solution(4))
# Out:
# Odd
# Even
