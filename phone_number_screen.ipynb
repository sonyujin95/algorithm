# %% [markdown]
# ![phone_number_screen.png](attachment:phone_number_screen.png)

# %%
def solution(phone_number):
    # phone_number(입력값)에서 뒷 네자리 전까지 *표시 + 마지막 네번째 자리 표시(숫자)
    return "*"*(len(phone_number)-4) + phone_number[-4:]
