# %% [markdown]
# ![seoul_kim.png](attachment:seoul_kim.png)

# %%
def findKim(seoul):
    return "김서방은 {}에 있다".format(seoul.index('Kim'))


# 실행을 위한 테스트코드입니다.
print(findKim(["Jane", "Kim"]))
print(findKim(["Queen", "Tod", "Kim"]))
# Out:
# 김서방은 1에 있다
# 김서방은 2에 있다
