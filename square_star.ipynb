# %% [markdown]
# ![square_star.png](attachment:square_star.png)

# %%
a, b = map(int, input().strip().split(' '))


for i in range(b):
    for j in range(a):
        print('*', end="")
        
    print()
# Out:
# 5 3
# *****
# *****
# *****
