# %% [markdown]
# ![count_p_y.png](attachment:count_p_y.png)

# %%
def solution(s):
    return s.lower().count('p') == s.lower().count('y')   # p와 y를 소문자화 시켜서 소문자 개수 비교

# 입출력 예 test
print(solution("pPoooyY"))
print(solution("Pyy"))
# Out:
# True
# False
