# %% [markdown]
# ![harshad_number.png](attachment:harshad_number.png)

# %%
def solution(x):
    # n은 하샤드 수인가?
    return x % sum([int(c) for c in str(x)]) == 0
    # str(x)의 인덱스 값을 sum 안에서 다 더해주고, 나눴을 때 0인지 판단
