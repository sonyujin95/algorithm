# %% [markdown]
# ![divisor_sum.png](attachment:divisor_sum.png)

# %%
def solution(n):                  
    sum = 0                   # 초기값
    for i in range(1,n+1):   # n+1을 해야 그 전 수인 n까지 반복
        if n % i == 0:       # n이 i로 나뉘어서 나머지가 0이면(즉 약수이면)
            sum += i         # i를 더해라 
    return sum               # 약수들의 합 리턴
