# %% [markdown]
# ![reverse_int.png](attachment:reverse_int.png)

# %%
def solution(n):
    n = list(str(n))          # 정수 n을 str로 변환하고 이를 list형식으로 변환한다.
    n.sort(reverse=True)      # list n을 내림차순으로 정렬한다.
    
    return int("".join(n))    # list를 str로 "".join() 변환해준 뒤에 int로 바꿔서 return한다.
