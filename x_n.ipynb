# %% [markdown]
# ![x_n.png](attachment:x_n.png)

# %%
def solution(x, n):
    
    answer = [  ]                # 빈 리스트 생성
    for i in range (1,n+1):     # i를 1부터 n개 반복 
        answer.append(x*i)       # 리스트에 x * i 넣기
    return answer
