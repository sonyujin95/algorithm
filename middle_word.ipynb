# %% [markdown]
# ![middle_word.png](attachment:middle_word.png)

# %%
def solution(s):
    if len(s) % 2 != 0:       # 글자 길이가 홀수라면
        return s[len(s)//2]   # 가운데 글자 반환
    else:
        return s[(len(s)//2)-1:(len(s)//2)+1]  # 짝수이면 중간의 왼쪽과 오른쪽을 같이 출력
    
# 입출력 예
print(solution("abcde"))
print(solution("qwer"))
# Out:
# c
# we
